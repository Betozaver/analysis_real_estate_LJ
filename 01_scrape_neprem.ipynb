# %%
# %pip install undetected-chromedriver
# Out:
# Requirement already satisfied: undetected-chromedriver in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (3.5.5)
# Requirement already satisfied: selenium>=4.9.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from undetected-chromedriver) (4.33.0)
# Requirement already satisfied: requests in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from undetected-chromedriver) (2.32.4)
# Requirement already satisfied: websockets in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from undetected-chromedriver) (15.0.1)
# Requirement already satisfied: urllib3[socks]~=2.4.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.13.2 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from requests->undetected-chromedriver) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from requests->undetected-chromedriver) (3.10)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver) (2.4.0)
# Requirement already satisfied: outcome in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from trio-websocket~=0.12.2->selenium>=4.9.0->undetected-chromedriver) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from urllib3[socks]~=2.4.0->selenium>=4.9.0->undetected-chromedriver) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium>=4.9.0->undetected-chromedriver) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
#from tabulate import tabulate
import csv
import time
import random

# %%
def scrape_nepremicnine_stanovanja():
    base_url = "https://www.nepremicnine.net/oglasi-prodaja/ljubljana-mesto/stanovanje"
    headers = ["NASLOV", "CENA", "OPIS", "m2", "LETO", "NASTROPJE", "ZEMLJISCE"]
    data = []

    driver = uc.Chrome()
    # when you go to the URL click the show last page and enter the number +1 (so if its page 34 enter 35)
    for page in range(1, 35):  # pages 1 to 34 inclusive
        if page == 1:
            url = base_url + "/"
        else:
            url = f"{base_url}/{page}/"

        print(f"Scraping page {page}...")
        driver.get(url)

        time.sleep(random.uniform(5, 8))  # wait like a human

        ads = driver.find_elements(By.CLASS_NAME, "property-details")

        for ad in ads:
            try:
                naslov = ad.find_element(By.CLASS_NAME, "url-title-d").text
                price = ad.find_element(By.TAG_NAME, "h6").text
                description = ad.find_element(By.TAG_NAME, "p").text
                ul = ad.find_element(By.TAG_NAME, "ul")
                lis = ul.find_elements(By.TAG_NAME, "li")
                m2 = leto = nastropje = zemljisce = "N/A"
                for li in lis:
                    try:
                        img = li.find_element(By.TAG_NAME, "img")
                        src = img.get_attribute("src")
                        value = li.text.strip()

                        if "velikost.svg" in src:
                            m2 = value
                        elif "leto.svg" in src:
                            leto = value
                        elif "nadstropje.svg" in src:
                            nastropje = value
                        elif "zemljisce.svg" in src:
                            zemljisce = value
                    except:
                        continue
                data.append([naslov, price, description, m2, leto, nastropje, zemljisce])
            except:
                continue

    driver.quit()

    with open("stanovanja.csv", "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(headers)  # Write header row
        writer.writerows(data)    # Write all data rows

    print("✅ Data exported to stanovanja.csv")

scrape_nepremicnine_stanovanja()
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
# Scraping page 33...
# Scraping page 34...
# ✅ Data exported to stanovanja.csv

# %%
def scrape_nepremicnine_hisa():
    base_url = "https://www.nepremicnine.net/oglasi-prodaja/ljubljana-mesto/hisa"
    headers = ["NASLOV", "CENA", "OPIS", "m2", "LETO", "NASTROPJE", "ZEMLJISCE"]
    data = []

    driver = uc.Chrome()
    # when you go to the URL click the show last page and enter the number +1 (so if its page 34 enter 35)
    for page in range(1, 16):  # pages 1 to 15 inclusive
        if page == 1:
            url = base_url + "/"
        else:
            url = f"{base_url}/{page}/"

        print(f"Scraping page {page}...")
        driver.get(url)

        time.sleep(random.uniform(5, 8))  # wait like a human

        ads = driver.find_elements(By.CLASS_NAME, "property-details")

        for ad in ads:
            try:
                naslov = ad.find_element(By.CLASS_NAME, "url-title-d").text
                price = ad.find_element(By.TAG_NAME, "h6").text
                description = ad.find_element(By.TAG_NAME, "p").text
                ul = ad.find_element(By.TAG_NAME, "ul")
                lis = ul.find_elements(By.TAG_NAME, "li")
                m2 = leto = nastropje = zemljisce = "N/A"
                for li in lis:
                    try:
                        img = li.find_element(By.TAG_NAME, "img")
                        src = img.get_attribute("src")
                        value = li.text.strip()

                        if "velikost.svg" in src:
                            m2 = value
                        elif "leto.svg" in src:
                            leto = value
                        elif "nadstropje.svg" in src:
                            nastropje = value
                        elif "zemljisce.svg" in src:
                            zemljisce = value
                    except:
                        continue
                data.append([naslov, price, description, m2, leto, nastropje, zemljisce])
            except:
                continue

    driver.quit()

    with open("hise.csv", "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(headers)  # Write header row
        writer.writerows(data)    # Write all data rows

    print("✅ Data exported to hise.csv")
scrape_nepremicnine_hisa()
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# ✅ Data exported to hise.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
