# %%
# %pip install pandas
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_csv('ETN_SLO_2007_KPP_KPP_DELISTAVB_20250615.csv', sep=',')

# %%
deli_stavb = pd.DataFrame(df_1)

# %%
pd.options.display.max_columns
pd.options.display.max_rows
# Out:
# 60

# %%
deli_stavb.head()
# Out:
#    ID_POSLA  SIFRA_KO      IME_KO     OBCINA  STEVILKA_STAVBE  \
# 0    -12848       660    STUDENCI    MARIBOR             4431
# 1    -12848       660    STUDENCI    MARIBOR             4431
# 2    -14568      1725  AJDOVŠČINA  LJUBLJANA              347
# 3    -14569      2636    BEŽIGRAD  LJUBLJANA             3403
# 4    -14979      2604     BERTOKI      KOPER             4202
#
#    STEVILKA_DELA_STAVBE  PARCELNA_STEVILKA_ZA_GEOLOKACIJO  \
# 0                  42.0                               NaN
# 1                   3.0                               NaN
# 2                   9.0                               NaN
# 3                  81.0                               NaN
# 4                   4.0                               NaN
#
#    INTERNA_OZNAKA_DELA_STAVBE  EVIDENTIRANOST_DELA_STAVBE    NASELJE  ...  \
# 0                         NaN                           1    MARIBOR  ...
# 1                         NaN                           1    MARIBOR  ...
# ...

# %%
#deli_stavb = deli_stavb.drop(columns='PARCELNA_STEVILKA_ZA_GEOLOKACIJO')

# %%
df_2 = pd.read_csv('ETN_SLO_2007_KPP_KPP_POSLI_20250615.csv', sep=',')

# %%
df_2.head()
# Out:
#    ID_POSLA  VRSTA_KUPOPRODAJNEGA_POSLA DATUM_UVELJAVITVE  \
# 0    -12890                           1        09.02.2007
# 1    -12894                           1        09.02.2007
# 2    -13408                           1        26.02.2007
# 3    -15169                           1        23.03.2007
# 4    -15191                           1        26.03.2007
#
#   DATUM_SKLENITVE_POGODBE  POGODBENA_CENA_ODSKODNINA  VKLJUCENOST_DDV  \
# 0              06.03.2007                  155000.00                0
# 1              22.01.2007                   87630.00                0
# 2              18.01.2007                   41729.26                0
# 3              12.03.2007                  117240.00                0
# 4              16.02.2007                     728.83                0
#
#    STOPNJA_DDV  DATUM_IZTEKA_LIZINGA  DATUM_PRENEHANJA_LIZINGA  \
# 0          NaN                   NaN                       NaN
# 1          NaN                   NaN                       NaN
# ...

# %%
kpp_posli = pd.DataFrame(df_2)

# %%
kpp_posli.head()
# Out:
#    ID_POSLA  VRSTA_KUPOPRODAJNEGA_POSLA DATUM_UVELJAVITVE  \
# 0    -12890                           1        09.02.2007
# 1    -12894                           1        09.02.2007
# 2    -13408                           1        26.02.2007
# 3    -15169                           1        23.03.2007
# 4    -15191                           1        26.03.2007
#
#   DATUM_SKLENITVE_POGODBE  POGODBENA_CENA_ODSKODNINA  VKLJUCENOST_DDV  \
# 0              06.03.2007                  155000.00                0
# 1              22.01.2007                   87630.00                0
# 2              18.01.2007                   41729.26                0
# 3              12.03.2007                  117240.00                0
# 4              16.02.2007                     728.83                0
#
#    STOPNJA_DDV  DATUM_IZTEKA_LIZINGA  DATUM_PRENEHANJA_LIZINGA  \
# 0          NaN                   NaN                       NaN
# 1          NaN                   NaN                       NaN
# ...

# %%
df_3 = pd.read_csv('ETN_SLO_2007_KPP_KPP_ZEMLJISCA_20250615.csv', sep=',')

# %%
kpp_zemlja = pd.DataFrame(df_3)

# %%
kpp_zemlja.head()
# Out:
#    ID_POSLA  SIFRA_KO              IME_KO   OBCINA PARCELNA_STEVILKA  \
# 0    -20565       168  DOLINA PRI LENDAVI  LENDAVA               926
# 1    -20565       168  DOLINA PRI LENDAVI  LENDAVA               928
# 2    -20565       168  DOLINA PRI LENDAVI  LENDAVA              1088
# 3    -20565       168  DOLINA PRI LENDAVI  LENDAVA               927
# 4    -20565       168  DOLINA PRI LENDAVI  LENDAVA               929
#
#    VRSTA_ZEMLJISCA  VRSTA_TRAJNEGA_NASADA  STAROST_TRAJNEGA_NASADA  \
# 0               10                    NaN                      NaN
# 1                7                    NaN                      NaN
# 2                7                    NaN                      NaN
# 3                7                    NaN                      NaN
# 4               10                    NaN                      NaN
#
#   PRODANI_DELEZ_PARCELE OPOMBE_O_NEPREMICNINI  POVRSINA_PARCELE  \
# 0                   1/1                   NaN             454.0
# ...

# %%
frames=[deli_stavb, kpp_posli, kpp_zemlja]
merged = deli_stavb.merge(kpp_posli, on='ID_POSLA', how='outer')
df_2007= merged.merge(kpp_zemlja, on='ID_POSLA', how='outer')

# %%
df_2007.head()
# Out:
#    ID_POSLA  SIFRA_KO_x  IME_KO_x  OBCINA_x  STEVILKA_STAVBE  \
# 0   -183401         NaN       NaN       NaN              NaN
# 1   -183401         NaN       NaN       NaN              NaN
# 2   -183401         NaN       NaN       NaN              NaN
# 3   -182191         NaN       NaN       NaN              NaN
# 4   -167268      2490.0  POSTOJNA  POSTOJNA           2091.0
#
#    STEVILKA_DELA_STAVBE  PARCELNA_STEVILKA_ZA_GEOLOKACIJO  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   5.0                               NaN
#
#    INTERNA_OZNAKA_DELA_STAVBE  EVIDENTIRANOST_DELA_STAVBE   NASELJE  ...  \
# 0                         NaN                         NaN       NaN  ...
# 1                         NaN                         NaN       NaN  ...
# ...

# %%
df_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28622 entries, 0 to 28621
# Data columns (total 69 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   ID_POSLA                                     28622 non-null  int64
#  1   SIFRA_KO_x                                   22498 non-null  float64
#  2   IME_KO_x                                     22498 non-null  object
#  3   OBCINA_x                                     22498 non-null  object
#  4   STEVILKA_STAVBE                              22498 non-null  float64
#  5   STEVILKA_DELA_STAVBE                         22486 non-null  float64
#  6   PARCELNA_STEVILKA_ZA_GEOLOKACIJO             0 non-null      float64
#  7   INTERNA_OZNAKA_DELA_STAVBE                   0 non-null      float64
#  8   EVIDENTIRANOST_DELA_STAVBE                   22498 non-null  float64
# ...

# %%
#df_2007.to_csv('df_2007.csv')

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean = df_2007.drop_duplicates(subset='ID_POSLA', keep='last')

# %%
#df_clean.to_csv('clean_2007.csv')

# %%
nov_df = pd.read_csv('clean_2_2007.csv')

# %%
nov_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3838 entries, 0 to 3837
# Data columns (total 60 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   field1                                       3838 non-null   int64
#  1   ID_POSLA                                     3838 non-null   int64
#  2   SIFRA_KO_x                                   3838 non-null   float64
#  3   IME_KO_x                                     3838 non-null   object
#  4   OBCINA_x                                     3838 non-null   object
#  5   STEVILKA_STAVBE                              3838 non-null   float64
#  6   STEVILKA_DELA_STAVBE                         3836 non-null   float64
#  7   EVIDENTIRANOST_DELA_STAVBE                   3838 non-null   float64
#  8   NASELJE                                      3577 non-null   object
# ...
