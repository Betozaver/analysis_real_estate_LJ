# %%
# %pip install pandas 
# %pip install numpy
# Out:
# Requirement already satisfied: pandas in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
stavbe2023 = pd.read_csv(r"clean_GURS\new_prodaja2023.csv", sep=',', encoding='utf-8')
stavbe2023.sample(10)
# Out:
#                      ime_ko    naselje  letnica_izgradnje  m2_bruto  m2_neto  \
# 2303              ZADOBROVA  LJUBLJANA               1955     125.5     81.1
# 1586          SPODNJA ŠIŠKA  LJUBLJANA               2022      48.0     46.3
# 2085  ŠENTVID NAD LJUBLJANO  LJUBLJANA               1963      55.3     43.0
# 1724          ZGORNJA ŠIŠKA  LJUBLJANA               1978      49.5     48.0
# 2189                  TACEN  LJUBLJANA               2021     139.8     93.8
# 1290               BEŽIGRAD  LJUBLJANA               1934      69.7     57.6
# 117              NOVE JARŠE  LJUBLJANA               1981      41.3     36.3
# 1050              NADGORICA        NaN               2023     114.9     99.8
# 951                 STOŽICE  LJUBLJANA               1978      80.0     64.8
# 1991               DOBRUNJE  LJUBLJANA               1901      93.9     64.5
#
#       LETO    cena  novogradnja
# 2303  2023  253000          NaN
# 1586  2023  262000          1.0
# 2085  2023  145000          NaN
# 1724  2023  232500          NaN
# 2189  2023  422000          1.0
# 1290  2023  201000          NaN
# 117   2023  142000          NaN
# 1050  2023  367000          1.0
# 951   2023   18762          NaN
# 1991  2023  150000          NaN

# %%
stavbe2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ime_ko             2311 non-null   object
#  1   naselje            2294 non-null   object
#  2   letnica_izgradnje  2311 non-null   int64
#  3   m2_bruto           2311 non-null   float64
#  4   m2_neto            2308 non-null   float64
#  5   LETO               2311 non-null   int64
#  6   cena               2311 non-null   int64
#  7   novogradnja        377 non-null    float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 144.6+ KB

# %%
#preparing the year column for Power BI
stavbe2023['LETO'] = pd.to_datetime("2023-01-01")

# %%
# creating a boolean column 'NOVOGRADNJA_1' based on 'NOVOGRADNJA'
stavbe2023['novogradnja_1'] = stavbe2023['novogradnja'] == 1

# Preview the new column
stavbe2023[['novogradnja', 'novogradnja_1']].sample(10)
# Out:
#       novogradnja  novogradnja_1
# 632           1.0           True
# 1060          NaN          False
# 1675          NaN          False
# 1952          1.0           True
# 1005          NaN          False
# 667           NaN          False
# 618           NaN          False
# 1594          NaN          False
# 2058          NaN          False
# 2003          NaN          False

# %%
#Printing the number of rows with missing values in 'm2_neto' column
stavbe2023[stavbe2023['m2_neto'].isna()]
# Out:
#              ime_ko    naselje  letnica_izgradnje  m2_bruto  m2_neto  \
# 636        BEŽIGRAD  LJUBLJANA               1996     103.6      NaN
# 1315  ZGORNJA ŠIŠKA  LJUBLJANA               1967      65.6      NaN
# 1640          TABOR  LJUBLJANA               1970      36.7      NaN
#
#            LETO    cena  novogradnja  novogradnja_1
# 636  2023-01-01  430000          NaN          False
# 1315 2023-01-01  202000          NaN          False
# 1640 2023-01-01  180000          NaN          False

# %%
def oceni_sobnost(m2):
    if pd.isna(m2):
        return None
    if m2 < 35:
        return 1
    elif m2 < 50:
        return 2
    elif m2 < 70:
        return 3
    elif m2 < 90:
        return 4
    elif m2 < 110:
        return 5
    else:
        return 6

# %%
stavbe2020['sobnost_ocenjena'] = stavbe2020['m2_neto'].apply(oceni_sobnost)

# %%
stavbe2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2860 entries, 0 to 2859
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ime_ko             2860 non-null   object
#  1   naselje            2842 non-null   object
#  2   letnica_izgradnje  2860 non-null   int64
#  3   m2_bruto           2860 non-null   int64
#  4   m2_neto            2860 non-null   int64
#  5   LETO               2860 non-null   datetime64[ns]
#  6   cena               2860 non-null   int64
#  7   novogradnja        516 non-null    float64
#  8   novogradnja_1      2860 non-null   bool
#  9   sobnost_ocenjena   2860 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(5), object(2)
# memory usage: 204.0+ KB

# %%
# Droping the original 'NOVOGRADNJA' column, as we now have 'NOVOGRADNJA_1' which has the same information in a boolean format.
stavbe2020.drop(columns=['novogradnja'], inplace=True)

# %%
#Printing the number of rows with missing values in 'm2_neto' column
stavbe2020[stavbe2020['m2_neto'].isna()]
# Out:
# Empty DataFrame
# Columns: [ime_ko, naselje, letnica_izgradnje, m2_bruto, m2_neto, LETO, cena, novogradnja_1, sobnost_ocenjena]
# Index: []

# %%
stavbe2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2860 entries, 0 to 2859
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ime_ko             2860 non-null   object
#  1   naselje            2842 non-null   object
#  2   letnica_izgradnje  2860 non-null   int64
#  3   m2_bruto           2860 non-null   int64
#  4   m2_neto            2860 non-null   int64
#  5   LETO               2860 non-null   datetime64[ns]
#  6   cena               2860 non-null   int64
#  7   novogradnja_1      2860 non-null   bool
#  8   sobnost_ocenjena   2860 non-null   int64
# dtypes: bool(1), datetime64[ns](1), int64(5), object(2)
# memory usage: 181.7+ KB

# %%
# Uniforming the column names to lowercase
stavbe2020.columns = [col.lower() for col in stavbe2020.columns]

# %%
#uniforming the all values in all the columns to lowercase
for col in stavbe2020.columns:
    if stavbe2020[col].dtype == 'object':
        stavbe2020[col] = stavbe2020[col].str.lower()

# %%
stavbe2020['ime_ko'].unique()
# Out:
# array(['kašelj', 'bežigrad', 'brinje i', 'karlovško predmestje', 'vič',
#        'spodnja šiška', 'šentvid nad ljubljano', 'poljansko predmestje',
#        'trnovsko predmestje', 'dravlje', 'moste', 'slape', 'štepanja vas',
#        'stožice', 'tabor', 'črnuče', 'zelena jama', 'zgornja šiška',
#        'šentpeter', 'dobrova', 'brinje ii', 'gradišče ii', 'gradišče i',
#        'ljubljana mesto', 'šmartno pod šmarno goro', 'dobrunje', 'rudnik',
#        'udmat', 'zadobrova', 'ajdovščina', 'brdo', 'ježica', 'prule',
#        'glince', 'vižmarje', 'podmolnik', 'nove jarše',
#        'krakovsko predmestje', 'bizovik', 'tacen', 'podsmreka', 'javor',
#        'golovec', 'trebeljevo', 'nadgorica', 'šmartno ob savi',
#        'gameljne', 'šujica', 'stanežiče', 'iška loka', 'lipoglav',
#        'sostro', 'volavlje', 'grič', 'podgorica', 'tomišelj'],
#       dtype=object)

# %%
# checking all the empty values in the 'naselje' column
stavbe2020[stavbe2020['naselje'].isna()]
# Out:
#                      ime_ko naselje  letnica_izgradnje  m2_bruto  m2_neto  \
# 56    šentvid nad ljubljano     NaN               2019       166      127
# 66                   kašelj     NaN               2018       162        0
# 586                  kašelj     NaN               2018       147        0
# 594         šmartno ob savi     NaN               2019       126      126
# 689               zadobrova     NaN               2019       147        0
# 840               zadobrova     NaN               2019       146        0
# 1217               lipoglav     NaN               1995        82       65
# 1274        šmartno ob savi     NaN               2019       126      126
# 1418               volavlje     NaN               1970        72       56
# 1453   poljansko predmestje     NaN               1895        64       39
# 1548                 kašelj     NaN               2018       147        0
# 1705                 kašelj     NaN               2019       137      137
# 1809                  javor     NaN               1990        56       52
# 1820                 kašelj     NaN               1970        66       41
# 2000                 kašelj     NaN               1972        64       41
# 2652                  tabor     NaN               1843        92       92
# 2747                 kašelj     NaN               2019       137      137
# 2808              nadgorica     NaN               1946       104      104
#
#            leto    cena  novogradnja_1  sobnost_ocenjena
# 56   2020-01-01  200000          False                 6
# 66   2020-01-01  231000           True                 1
# 586  2020-01-01  240000           True                 1
# 594  2020-01-01  270000          False                 6
# 689  2020-01-01  300000          False                 1
# 840  2020-01-01  300000          False                 1
# 1217 2020-01-01  150000          False                 3
# 1274 2020-01-01  290000          False                 6
# 1418 2020-01-01   29000          False                 3
# 1453 2020-01-01   81500          False                 2
# 1548 2020-01-01  215000           True                 1
# 1705 2020-01-01  185000          False                 6
# 1809 2020-01-01   17000          False                 3
# 1820 2020-01-01   80841          False                 2
# 2000 2020-01-01   40000          False                 2
# 2652 2020-01-01  145000          False                 5
# 2747 2020-01-01  180000          False                 6
# 2808 2020-01-01  148000          False                 5

# %%
# changing all the empty values in the 'naselje' column to 'ljubljana'
stavbe2020['naselje'].fillna('ljubljana', inplace=True)
# Out:
# C:\Users\gaj\AppData\Local\Temp\ipykernel_15444\1464791112.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   stavbe2020['naselje'].fillna('ljubljana', inplace=True)

# %%
stavbe2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2860 entries, 0 to 2859
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ime_ko             2860 non-null   object
#  1   naselje            2860 non-null   object
#  2   letnica_izgradnje  2860 non-null   int64
#  3   m2_bruto           2860 non-null   int64
#  4   m2_neto            2860 non-null   int64
#  5   leto               2860 non-null   datetime64[ns]
#  6   cena               2860 non-null   int64
#  7   novogradnja_1      2860 non-null   bool
#  8   sobnost_ocenjena   2860 non-null   int64
# dtypes: bool(1), datetime64[ns](1), int64(5), object(2)
# memory usage: 181.7+ KB

# %%
stavbe2020.to_csv(r"clean_GURS\stavbe2020_cleaned.csv", index=False, encoding='utf-8')
