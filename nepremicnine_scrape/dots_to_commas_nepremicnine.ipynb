# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv(r"D:\projects_Sara\analysis_real_estate_LJ\nepremicnine_scrape\nepremicnine_06082025_cleaned.csv", sep= ';', encoding='utf-8')

# %%
df.sample(5)
# Out:
#          cena     mestna_cetrt sobnost_ocenjena    naselje leto_izgradnje  \
# 335  920000,0  LJUBLJANA MESTO              2,0     center         2025,0
# 289  850000,0  LJUBLJANA MESTO              3,0     center         2023,0
# 89   250000,0          DRAVLJE              5,0    dravlje         1978,0
# 715  520000,0  LJUBLJANA MESTO              4,0  stara lj.         1803,0
# 69   280000,0           ČRNUČE              5,0     črnuče         1936,0
#
#     total_m2  is_apartment  novogradnja_1  leto        price_per_m2
# 335   207,13             1           True  2025   4441,654999275817
# 289   115,09             1           True  2025  7385,5243722304285
# 89      46,0             1          False  2025   5434,782608695652
# 715    137,0             1          False  2025   3795,620437956205
# 69      74,2             1          False  2025   3773,584905660377

# %%
df['DATUM'] = pd.to_datetime("2025-01-01")

# %%
df.head()
# Out:
#         cena mestna_cetrt sobnost_ocenjena   naselje leto_izgradnje total_m2  \
# 0  460457,99     BEŽIGRAD              3,0  bežigrad         2024,0     85,2
# 1  576250,99     BEŽIGRAD              4,0  bežigrad         2024,0   107,45
# 2   488949,3     BEŽIGRAD              3,0  bežigrad         2024,0    110,4
# 3  570648,89     BEŽIGRAD              3,0  bežigrad         2024,0    112,5
# 4  777582,99     BEŽIGRAD              4,0  bežigrad         2024,0   162,91
#
#    is_apartment  novogradnja_1  leto       price_per_m2      DATUM
# 0             1           True  2025  5404,436502347417 2025-01-01
# 1             1           True  2025  5362,968729641693 2025-01-01
# 2             1           True  2025  4428,888586956521 2025-01-01
# 3             1           True  2025  5072,434577777778 2025-01-01
# 4             1           True  2025  4773,083236142656 2025-01-01

# %%
df.to_csv(r"D:\projects_Sara\analysis_real_estate_LJ\nepremicnine_scrape\nepremicnine_final.csv", sep=';', encoding='utf-8', index=False)
