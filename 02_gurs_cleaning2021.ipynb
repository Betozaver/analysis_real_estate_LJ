# %%
# %pip install pandas 
# %pip install numpy
# Out:
# Requirement already satisfied: pandas in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
stavbe2021 = pd.read_csv(r"clean_GURS\new_prodaja2021.csv", sep=',', encoding='utf-8')
stavbe2021.sample(10)
# Out:
#                    ime_ko    naselje  letnica_izgradnje  m2_bruto  m2_neto  \
# 1108  TRNOVSKO PREDMESTJE  LJUBLJANA               2020      80.1     67.2
# 1507  TRNOVSKO PREDMESTJE  LJUBLJANA               1967      61.5     46.9
# 1419        SPODNJA ŠIŠKA  LJUBLJANA               1965      53.3     52.0
# 1184                TABOR  LJUBLJANA               1908      24.7     24.7
# 2846             VIŽMARJE  LJUBLJANA               1959      80.6     62.4
# 1155               GLINCE  LJUBLJANA               2020     130.6     72.3
# 1333             BEŽIGRAD  LJUBLJANA               1972      68.2     62.5
# 452                 MOSTE  LJUBLJANA               1958      54.0     48.6
# 822                 MOSTE  LJUBLJANA               1969      19.9     19.9
# 747            NOVE JARŠE  LJUBLJANA               1982      41.9     38.4
#
#       LETO      cena  novogradnja
# 1108  2021  300000.0          NaN
# 1507  2021  142000.0          NaN
# 1419  2021  120000.0          NaN
# 1184  2021   77000.0          NaN
# 2846  2021  183000.0          NaN
# 1155  2021  288000.0          1.0
# 1333  2021  130000.0          NaN
# 452   2021   93000.0          NaN
# 822   2021  105600.0          NaN
# 747   2021  140000.0          NaN

# %%
stavbe2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927 entries, 0 to 2926
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ime_ko             2927 non-null   object
#  1   naselje            2902 non-null   object
#  2   letnica_izgradnje  2927 non-null   int64
#  3   m2_bruto           2927 non-null   float64
#  4   m2_neto            2927 non-null   float64
#  5   LETO               2927 non-null   int64
#  6   cena               2926 non-null   float64
#  7   novogradnja        351 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 183.1+ KB

# %%
#preparing the year column for Power BI
stavbe2021['LETO'] = pd.to_datetime("2021-01-01")

# %%
# creating a boolean column 'NOVOGRADNJA_1' based on 'NOVOGRADNJA'
stavbe2021['novogradnja_1'] = stavbe2021['novogradnja'] == 1

# %%
stavbe2021[['novogradnja', 'novogradnja_1']].sample(10)
# Out:
#       novogradnja  novogradnja_1
# 2517          NaN          False
# 1092          NaN          False
# 40            1.0           True
# 1642          NaN          False
# 1528          NaN          False
# 1356          NaN          False
# 2525          NaN          False
# 591           NaN          False
# 1794          NaN          False
# 1422          NaN          False

# %%
#Printing the number of rows with missing values in 'm2_neto' column
stavbe2021[stavbe2021['m2_neto'].isna()]
# Out:
# Empty DataFrame
# Columns: [ime_ko, naselje, letnica_izgradnje, m2_bruto, m2_neto, LETO, cena, novogradnja]
# Index: []

# %%
def oceni_sobnost(m2):
    if pd.isna(m2):
        return None
    if m2 < 35:
        return 1
    elif m2 < 50:
        return 2
    elif m2 < 70:
        return 3
    elif m2 < 90:
        return 4
    elif m2 < 110:
        return 5
    else:
        return 6

# %%
stavbe2021['sobnost_ocenjena'] = stavbe2021['m2_neto'].apply(oceni_sobnost)

# %%
stavbe2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927 entries, 0 to 2926
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ime_ko             2927 non-null   object
#  1   naselje            2902 non-null   object
#  2   letnica_izgradnje  2927 non-null   int64
#  3   m2_bruto           2927 non-null   float64
#  4   m2_neto            2927 non-null   float64
#  5   LETO               2927 non-null   int64
#  6   cena               2926 non-null   float64
#  7   novogradnja        351 non-null    float64
#  8   sobnost_ocenjena   2927 non-null   int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 205.9+ KB

# %%
# Droping the original 'NOVOGRADNJA' column, as we now have 'NOVOGRADNJA_1' which has the same information in a boolean format.
stavbe2021.drop(columns=['novogradnja'], inplace=True)

# %%
#Printing the number of rows with missing values in 'cena' column
stavbe2021[stavbe2021['cena'].isna()]
# Out:
#        ime_ko    naselje  letnica_izgradnje  m2_bruto  m2_neto  LETO  cena  \
# 484  BRINJE I  LJUBLJANA               1964      75.7     65.7  2021   NaN
#
#      sobnost_ocenjena
# 484                 3

# %%
stavbe2021.drop(index=484, inplace=True)  # Dropping the row with index 484 as it has a missing 'cena' value

# %%
# Uniforming the column names to lowercase
stavbe2021.columns = [col.lower() for col in stavbe2021.columns]

# %%
#uniforming the all values in all the columns to lowercase
for col in stavbe2021.columns:
    if stavbe2021[col].dtype == 'object':
        stavbe2021[col] = stavbe2021[col].str.lower()

# %%
stavbe2021['ime_ko'].unique()
# Out:
# array(['zgornja šiška', 'šentpeter', 'rudnik', 'vič', 'spodnja šiška',
#        'glince', 'ajdovščina', 'moste', 'bežigrad',
#        'karlovško predmestje', 'črnuče', 'šentvid nad ljubljano',
#        'volavlje', 'golovec', 'tabor', 'trnovsko predmestje', 'dravlje',
#        'prule', 'slape', 'nove jarše', 'vižmarje', 'ježica',
#        'poljansko predmestje', 'šmartno pod šmarno goro', 'brinje i',
#        'štepanja vas', 'udmat', 'zelena jama', 'gameljne', 'gradišče ii',
#        'gradišče i', 'ljubljana mesto', 'dobrunje', 'dobrova',
#        'stanežiče', 'zadobrova', 'kašelj', 'stožice', 'trebeljevo',
#        'tomišelj', 'tacen', 'brdo', 'podgorica', 'sostro',
#        'krakovsko predmestje', 'brinje ii', 'nadgorica', 'podmolnik',
#        'grič', 'bizovik', 'podsmreka', 'šmartno ob savi', 'rašica',
#        'šujica', 'lipoglav'], dtype=object)

# %%
# checking all the empty values in the 'naselje' column
stavbe2021[stavbe2021['naselje'].isna()]
# Out:
#                    ime_ko naselje  letnica_izgradnje  m2_bruto  m2_neto  leto  \
# 207              vižmarje     NaN               2020     145.6      0.0  2021
# 261              vižmarje     NaN               2020     145.6      0.0  2021
# 357              vižmarje     NaN               2020     145.6      0.0  2021
# 427                 udmat     NaN               1975      58.8     58.8  2021
# 517                kašelj     NaN               2021     182.0      0.0  2021
# 705                 tacen     NaN               2013     124.1    102.3  2021
# 775                  grič     NaN               2019     191.7    179.6  2021
# 776                   vič     NaN               2000     149.4    112.6  2021
# 1190          gradišče ii     NaN               1930     108.5     86.8  2021
# 1233             vižmarje     NaN               2020     145.6      0.0  2021
# 1269              bizovik     NaN               2020     162.1      0.0  2021
# 1340             vižmarje     NaN               2020     145.6      0.0  2021
# 1415         štepanja vas     NaN               1925      93.0     64.0  2021
# 1465              bizovik     NaN               2020     162.1      0.0  2021
# 1509               kašelj     NaN               2017     272.3    125.2  2021
# 1541            nadgorica     NaN               1946     113.8    113.8  2021
# 1785               kašelj     NaN               2021     198.4      0.0  2021
# 1960             vižmarje     NaN               2020     145.6      0.0  2021
# 2141            nadgorica     NaN               1946     113.8    113.8  2021
# 2388           nove jarše     NaN               2020     107.7     55.6  2021
# 2416               kašelj     NaN               2021     182.0      0.0  2021
# 2662  trnovsko predmestje     NaN               1981      56.4     40.5  2021
# 2755            zadobrova     NaN               2019     142.5    135.6  2021
# 2823               kašelj     NaN               1990      61.8     49.4  2021
# 2862             vižmarje     NaN               2020     145.6      0.0  2021
#
#           cena  sobnost_ocenjena
# 207   200000.0                 1
# 261   207500.0                 1
# 357   292000.0                 1
# 427   160000.0                 3
# 517   190000.0                 1
# 705   530000.0                 5
# 775   250000.0                 6
# 776   239000.0                 6
# 1190  158000.0                 4
# 1233  200000.0                 1
# 1269  337500.0                 1
# 1340  220000.0                 1
# 1415  256000.0                 3
# 1465  365000.0                 1
# 1509  350000.0                 6
# 1541  148000.0                 6
# 1785  252945.0                 1
# 1960  205000.0                 1
# 2141  148000.0                 6
# 2388  185784.0                 3
# 2416  190000.0                 1
# 2662   30000.0                 2
# 2755  359000.0                 6
# 2823  120000.0                 2
# 2862  225000.0                 1

# %%
# changing all the empty values in the 'naselje' column to 'ljubljana'
stavbe2021['naselje'].fillna('ljubljana', inplace=True)
# Out:
# C:\Users\gaj\AppData\Local\Temp\ipykernel_17372\3111261597.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   stavbe2021['naselje'].fillna('ljubljana', inplace=True)

# %%
stavbe2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2926 entries, 0 to 2926
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ime_ko             2926 non-null   object
#  1   naselje            2926 non-null   object
#  2   letnica_izgradnje  2926 non-null   int64
#  3   m2_bruto           2926 non-null   float64
#  4   m2_neto            2926 non-null   float64
#  5   leto               2926 non-null   int64
#  6   cena               2926 non-null   float64
#  7   sobnost_ocenjena   2926 non-null   int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 205.7+ KB

# %%
stavbe2021.to_csv(r"clean_GURS\stavbe2021_cleaned.csv", index=False, encoding='utf-8')
