# %%
# %pip install pandas 
# %pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gaj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gaj\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:,.2f}'.format # Set display options for better readability
flet =pd.read_csv('stanovanja.csv', sep=';')
hise = pd.read_csv('hise.csv', sep=';')

# %%
flet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   NASLOV     816 non-null    object
#  1   CENA       816 non-null    object
#  2   OPIS       816 non-null    object
#  3   m2         816 non-null    object
#  4   LETO       816 non-null    int64
#  5   NASTROPJE  735 non-null    object
#  6   ZEMLJISCE  76 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 44.8+ KB

# %%
flet.head(5)
# Out:
#                                        NASLOV          CENA  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA  460.457,99 €
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA  576.250,99 €
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA  488.949,30 €
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA  570.648,89 €
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA  777.582,99 €
#
#                                                 OPIS         m2  LETO  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 85...   85,20 m2  2024
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 10...  107,45 m2  2024
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11...  110,40 m2  2024
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11...  112,50 m2  2024
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 16...  162,91 m2  2024
#
#   NASTROPJE ZEMLJISCE
# 0         1       NaN
# 1         1       NaN
# 2         1       NaN
# 3         P       NaN
# 4         P       NaN

# %%
flet['m2']=flet['m2'].str.replace(',', '.').str.replace(' m2', '').astype(float)

# %%
# Clean the CENA column and extract the first valid price
flet['CENA'] = (
	flet['CENA']
	.str.replace('.', '', regex=False)
	.str.replace(',', '.', regex=False)
	.str.replace('€', '', regex=False)
	.str.extract(r'(\d+\.\d+)')[0]  # extract the first float-like number
	.astype(float)
)

# %%
flet['cena_m2'] = flet['CENA'] / flet['m2']

# %%
flet['adaptirano'] = flet['OPIS'].str.contains('adaptirano', case=False, na=False).astype(int)
# case = False makes the search case-insensitive
# na = False ensures that NaN values are treated as False
#.astype(int) converts the boolean values to integers (0 or 1)

# %%
flet['adaptirano'].value_counts()
# Out:
# adaptirano
# 0    467
# 1    349
# Name: count, dtype: int64

# %%
import re

# %%
# Extract the year from the description if it exists (when 'adaptirano' is mentioned)
flet['leto_adaptacije'] = flet['OPIS'].str.extract(r'adaptirano.*?(\d{4})', flags=re.IGNORECASE)[0]

# %%
flet['leto_adaptacije'].unique()
# Out:
# array([nan, '2025', '2000', '2022', '2018', '2008', '2019', '2002',
#        '2010', '2020', '2014', '2016', '2023', '2005', '2015', '2017',
#        '1998', '2003', '2011', '2024', '2009', '1977', '2006', '2013',
#        '1997', '2007', '2021', '2012', '1994', '2004', '2001', '1995',
#        '1990', '1996', '1992'], dtype=object)

# %%
flet.to_csv('flet_blink.csv', index=True, sep=';')

# %%
flet['st_sob'] = flet['OPIS'].str.extract(r'(\d+)[^\d]{0,10}sobno', flags=re.IGNORECASE)[0].astype(float)

# %%
#print(flet[flet['st_sob'].isna()]['OPIS'])

# %%
maska_garsonjera = flet['st_sob'].isna() & flet['OPIS'].str.contains('garsonjera', case=False, na=False)
flet.loc[maska_garsonjera, 'st_sob'] = 0.5

# %%
flet.loc[224, 'st_sob'] = 0
flet.loc[233, 'st_sob'] = 0
flet.loc[253, 'st_sob'] = 2.0
flet.loc[435, 'st_sob'] = 0
flet.loc[471, 'st_sob'] = 0
flet.loc[576, 'st_sob'] = 18
flet.loc[757, 'st_sob'] = 0

# %% [markdown]
# Naredi: preglej vnose stanovanj, ki so bili zgrajeni pred 2000 in NISO adaptirani. Torej groupby SQL

# %% [markdown]
# #flet['lokacija']
# #flet['lokacija_grouped']

# %%
#zanka za kraje
kraji = ['šiška', 'vič', 'center', 'bežigrad', 'moste', 'dravlje', 'tabor', 'rožna dolina', 
         'trnovo', 'šentvid', 'rudnik', 'zalog', 'črnuče', 'polje', 'rožnik', 'gameljne', 'golovec', 'trnovo', 'koseze', 
         'kodeljevo', 'brdo', 'vrhovci', 'podutik', 'ježica', 'nove jarše', 'btc', 'fužine', 'štepanjsko naselje', 'kašelj', 'sostro', 
         'šmarna gora', 'brinje', 'brod', 'bs 3', 'črna vas', 'dobrunje', 'dolgi most', 'draveljska gmajna', 'galjevica', 'kolezija', 'litostroj', 
         'medno', 'mirje', 'murglje', 'nadgorica', 'poljane', 'prule', 'rakova jelša', 'savsko naselje', 'stanežiče', 'stara lj.', 'stožice', 'šentjakob', 'štepanja vas', 'tacen', 
         'tomačevo', 'tacen', 'tomačevo', 'vižmarje', 'vodmat', 'zelena jama', 'žale', 'zupančičeva jama', 'murgle', 'rakovnik', 'sneberje']

def extract_kraji(opis):
    for kraj in kraji:
        if kraj in opis.lower():
            return kraj
    else:
        return opis
    
flet['kraj'] = flet['OPIS'].apply(extract_kraji)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 16
#      13     else:
#      14         return opis
# ---> 16 flet['kraj'] = flet['OPIS'].apply(extract_kraji)
#
# File c:\Users\gaj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)   4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File c:\Users\gaj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\gaj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\gaj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\gaj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[45], line 11, in extract_kraji(opis)
#       9 def extract_kraji(opis):
#      10     for kraj in kraji:
# ---> 11         if kraj in opis.lower():
#      12             return kraj
#      13     else:
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
flet['kraj'].unique()
# Out:
# array(['bežigrad', 'črnuče', 'dravlje', 'center', 'moste', 'šiška',
#        'nove jarše', 'podutik', 'rožna dolina', 'rudnik', 'brdo',
#        'brinje', 'brod', 'bs 3', 'btc', 'črna vas', 'dobrunje',
#        'dolgi most', 'draveljska gmajna', 'fužine', 'galjevica', 'ježica',
#        'kodeljevo', 'kolezija', 'koseze', 'litostroj', 'vič', 'medno',
#        'mirje', 'murgle', 'trnovo', 'nadgorica', 'poljane', 'polje',
#        'prule', 'rakova jelša', 'rakovnik', 'savsko naselje', 'sneberje',
#        'gameljne', 'stanežiče', 'stara lj.', 'stožice', 'šentjakob',
#        'šentvid', 'štepanja vas', 'štepanjsko naselje', 'tabor', 'tacen',
#        'tomačevo', 'vižmarje', 'vodmat', 'zalog', 'zelena jama', 'kašelj',
#        'zupančičeva jama', nan], dtype=object)

# %%
kraji1 = ['bežigrad', 'črnuče', 'dravlje', 'center', 'moste', 'šiška',
       'nove jarše', 'podutik', 'rožna dolina', 'rudnik', 'brdo',
       'brinje', 'brod', 'bs 3', 'btc', 'črna vas', 'dobrunje',
       'dolgi most', 'draveljska gmajna', 'fužine', 'galjevica', 'ježica',
       'kodeljevo', 'kolezija', 'koseze', 'litostroj', 'vič', 'medno',
       'mirje', 'murgle', 'trnovo', 'nadgorica', 'poljane', 'polje',
       'prule', 'rakova jelša', 'rakovnik', 'savsko naselje', 'sneberje',
       'gameljne', 'stanežiče', 'stara lj.', 'stožice', 'šentjakob',
       'šentvid', 'štepanja vas', 'štepanjsko naselje', 'tabor', 'tacen',
       'tomačevo', 'vižmarje', 'vodmat', 'zalog', 'zelena jama', 'kašelj',
       'zupančičeva jama']

# %%
kraj_to_mestna_cetrt = {
    # Bežigrad
    'bežigrad': 'Bežigrad',
    'brinje': 'Bežigrad',
    'ježica': 'Posavje',
    'savsko naselje': 'Bežigrad',
    'stožice': 'Posavje',
    'tomačevo': 'Posavje',
    'zupančičeva jama': 'Bežigrad',

    # Center
    'center': 'Center',
    'mirje': 'Center',
    'poljane': 'Center', 
    'prule': 'Center',
    'rožna dolina': 'Rožnik',
    'stara lj.': 'Center',
    'tabor': 'Center',

    # Črnuče
    'črnuče': 'Črnuče',
    'brod': 'Šentvid',
    'nadgorica': 'Črnuče',
    'šentjakob': 'Šentvid',

    # Dravlje
    'dravlje': 'Dravlje',
    # (ni dodatnih naselij v tvojem seznamu)

    # Jarše
    'nove jarše': 'Jarše',
    'bs 3': 'Jarše',
    'btc': 'Jarše',
    'zelena jama': 'Jarše',
    'jarše': 'Jarše',       # dodano kot splošna referenca

    # Moste
    'moste': 'Moste',
    'fužine': 'Moste',
    'kodeljevo': 'Moste',
    'štepanja vas': 'Golovec',
    'štepanjsko naselje': 'Golovec',
    'vodmat': 'Moste',
    'selo': 'Moste',        # Selo pripada Mostem :contentReference[oaicite:6]{index=6}

    # Polje
    'polje': 'Polje',

    # Posavje
    # (v tvojem seznamu ni naselij, ki spadajo izključno sem)

    # Rožnik
    'vič': 'Vič',
    'brdo': 'Rožnik',
    'dolgi most': 'Vič',
    'vrhovce': 'Rožnik',

    # Rudnik
    'rudnik': 'Rudnik',
    'črna vas': 'Rudnik',
    'galjevica': 'Rudnik',
    'rakova jelša': 'Rudnik',
    'rakovnik': 'Rudnik',

    # Sostro
    'dobrunje': 'Sostro',
    'nadgorica': 'Črnuče',
    'kašelj': 'Sostro',
    'sneberje': 'Sostro',
    'zalog': 'Sostro',

    # Šentvid
    'šentvid': 'Šentvid',
    'medno': 'Šentvid',
    'vižmarje': 'Šentvid',
    'gunclje': 'Šentvid',
    'stanežiče': 'Šentvid',

    # Šiška
    'šiška': 'Šiška',
    'draveljska gmajna': 'Dravlje',
    'koseze': 'Šiška',
    'litostroj': 'Šiška',
    'podutik': 'Šiška',

    # Šmarna gora
    'šmarna gora': 'Šmarna gora',
    'gameljne': 'Šmarna gora',
    'stanežiče': 'Šmarna gora',
    'tacen': 'Šmarna gora',

    # Trnovo
    'trnovo': 'Trnovo',
    'murgle': 'Trnovo',

    # Vič
    'kolezija': 'Vič',
    'glince': 'Vič'
}

# %%
flet['mestna_cetrt'] = flet['kraj'].map(kraj_to_mestna_cetrt)

# %%
flet.head()
# Out:
#                                        NASLOV       CENA  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 460,457.99
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 576,250.99
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 488,949.30
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 570,648.89
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 777,582.99
#
#                                                 OPIS     m2     LETO  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 85...  85.20 2,024.00
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 10... 107.45 2,024.00
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11... 110.40 2,024.00
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11... 112.50 2,024.00
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 16... 162.91 2,024.00
#
#   NASTROPJE ZEMLJISCE  cena_m2  adaptirano leto_adaptacije  st_sob      kraj  \
# 0         1       NaN 5,404.44        0.00             NaN    3.00  bežigrad
# 1         1       NaN 5,362.97        0.00             NaN    4.00  bežigrad
# 2         1       NaN 4,428.89        0.00             NaN    3.00  bežigrad
# 3         P       NaN 5,072.43        0.00             NaN    3.00  bežigrad
# 4         P       NaN 4,773.08        0.00             NaN    4.00  bežigrad
#
#   mestna_cetrt
# 0     Bežigrad
# 1     Bežigrad
# 2     Bežigrad
# 3     Bežigrad
# 4     Bežigrad

# %%
flet['mestna_cetrt'] = flet['kraj'].map(kraj_to_mestna_cetrt).fillna('Neznano')

# %%
flet['mestna_cetrt'].value_counts()
# Out:
# mestna_cetrt
# Center         246
# Bežigrad       124
# Šiška          105
# Vič             67
# Moste           52
# Rožnik          37
# Rudnik          29
# Šentvid         28
# Jarše           24
# Dravlje         21
# Črnuče          19
# Posavje         19
# Trnovo          13
# Šmarna gora     10
# Sostro           9
# Polje            7
# Golovec          5
# Neznano          1
# Name: count, dtype: int64

# %%
#flet['kraj'].value_counts()

# %%
flet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 576
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NASLOV           815 non-null    object
#  1   CENA             815 non-null    float64
#  2   OPIS             815 non-null    object
#  3   m2               815 non-null    float64
#  4   LETO             815 non-null    float64
#  5   NASTROPJE        734 non-null    object
#  6   ZEMLJISCE        76 non-null     object
#  7   cena_m2          815 non-null    float64
#  8   adaptirano       815 non-null    float64
#  9   leto_adaptacije  346 non-null    object
#  10  st_sob           816 non-null    float64
#  11  kraj             815 non-null    object
#  12  mestna_cetrt     816 non-null    object
# dtypes: float64(6), object(7)
# memory usage: 121.5+ KB

# %% [markdown]
# Korekcija tipov podatkov:

# %%
pd.set_option('display.max_rows', None)

# %%
flet['adaptirano'].value_counts()
# Out:
# adaptirano
# 0.00    467
# 1.00    348
# Name: count, dtype: int64

# %%
flet = flet.drop(576)

# %% [markdown]
# Komentar: nadstropja? ali so pomembna?
# V primeru zemljišč... ali tovrstna stanovanje izločimo?

# %%
flet['st_sob'].value_counts().sum()
# Out:
# np.int64(815)

# %%
# Drop rows with missing values in 'm2' or 'st_sob' before plotting
flet_clean = flet.dropna(subset=['m2', 'st_sob'])
plt.scatter(data=flet_clean, x='m2', y='st_sob')

# %%
sobnost = flet.groupby('st_sob')['m2'].mean()

# %%
plt.plot(sobnost)

# %%
#prikaz stanovanj, ki imajo pripradajoče zemljišče. Stanovanja, ki nimajo zemljišča so bila 'NaN'.
zemljisce = flet[flet['ZEMLJISCE'].notna()]
zemljisce
# Out:
#                                                NASLOV       CENA  \
# 5                ČRNUČE, NARAVA ZASEBNOST TEHNOLOGIJA 489,000.00
# 37           BRDO, 3 - SOBNO, ATRIJSKO, NADSTANDARDNO 678,742.32
# 38                       BRDO, ATRIJSKO, TOP LOKACIJA 595,469.76
# 50                            BROD, MARINOVŠEVA CESTA 535,205.89
# 54                                               BS 3 168,600.00
# 58                                               BS 3 360,000.00
# 60                                           ČRNA VAS 530,000.00
# 68                                             ČRNUČE 190,000.00
# 69                                             ČRNUČE 280,000.00
# 70                                             ČRNUČE 495,000.00
# 73                                             ČRNUČE 585,000.00
# 74                                             ČRNUČE 650,000.00
# 75               ČRNUČE, NARAVA ZASEBNOST TEHNOLOGIJA 489,000.00
# 79                                         DOLGI MOST 435,000.00
# 127                                         KODELJEVO 265,000.00
# 130                                          KOLEZIJA 385,000.00
# 139                                      LJ. BEŽIGRAD 141,000.00
# 156                                      LJ. BEŽIGRAD 311,000.00
# 175                                      LJ. BEŽIGRAD 469,000.00
# 196                      LJ. BEŽIGRAD, ČERINOVA ULICA 397,600.00
# 207                 LJ. BEŽIGRAD, KAMNIŠKA ULICA /VRT 141,000.00
# 215                             LJ. BEŽIGRAD, STOŽICE 305,000.00
# 254                                        LJ. CENTER 387,000.00
# 273                                        LJ. CENTER 499,000.00
# 279                                        LJ. CENTER 499,000.00
# 280                                        LJ. CENTER 499,000.00
# 345                                        LJ. CENTER 550,000.00
# 381                            LJ. CENTER, GORNJI TRG 590,000.00
# 382                            LJ. CENTER, GORNJI TRG 590,000.00
# 391                        LJ. CENTER, MESARSKA CESTA 210,000.00
# 417                          LJ. CENTER, SLOMŠKOVA 11  84,900.00
# 426                             LJ. CENTER, STARI TRG 700,000.00
# 431                                LJ. CENTER, TRNOVO 395,000.00
# 444                                         LJ. MOSTE 220,000.00
# 445                                         LJ. MOSTE 260,000.00
# 447                                         LJ. MOSTE 330,000.00
# 450                                         LJ. MOSTE 399,000.00
# 452                                         LJ. MOSTE 300,000.00
# 453                                         LJ. MOSTE 595,000.00
# 455                          LJ. MOSTE, ATRIJ, TERASA 379,900.00
# 456                    LJ. MOSTE, ATRIJSKO STANOVANJE 400,000.00
# 458                             LJ. MOSTE, NOVE JARŠE 379,900.00
# 462                             LJ. MOSTE, ŠMARTINSKA 334,000.00
# 463                 LJ. MOSTE, V DVOSTANOVANJSKI HIŠI 270,000.00
# 466                      LJ. MOSTE, ZAKOTNIKOVA ULICA 325,000.00
# 469                             LJ. MOSTE, ZALOŠKA 26 236,000.00
# 480                                         LJ. ŠIŠKA 207,000.00
# 508                                         LJ. ŠIŠKA 290,000.00
# 525                                 LJ. ŠIŠKA, KOSEZE 350,000.00
# 584                             LJ. VIČ, ROŽNA DOLINA 699,000.00
# 614                    NOVE JARŠE, POLEG OŠ, S TERASO 379,900.00
# 625                                             POLJE 188,000.00
# 633                                             PRULE 550,000.00
# 639                                      RAKOVA JELŠA 250,000.00
# 640                              RAKOVA JELŠA, TRNOVO 330,000.00
# 656                                      ROŽNA DOLINA 719,000.00
# 664     ROŽNA DOLINA, 1KM CENTER, 300M ROŽNIK, TIVOLI 329,000.00
# 666  ROŽNA DOLINA, ATRIJSKO, 3 - SOBNO, NADSTANDARDNO 678,742.32
# 667              ROŽNA DOLINA, ATRIJSKO, TOP LOKACIJA 595,469.76
# 674                                            RUDNIK 470,000.00
# 676                                            RUDNIK 499,000.00
# 683                      RUDNIK, KARLOVŠKO PREDMESTJE 529,000.00
# 701                                         SP. ŠIŠKA 324,000.00
# 708                                  SREDNJE GAMELJNE 330,000.00
# 709                                         STANEŽIČE 675,000.00
# 710                                         STANEŽIČE 695,000.00
# 739                                         ŠENTJAKOB 439,000.00
# 740                                         ŠENTJAKOB 439,000.00
# 741                                         ŠENTJAKOB 475,000.00
# 742                                         ŠENTJAKOB 475,000.00
# 749                                           ŠENTVID 230,000.00
# 761                                          TOMAČEVO 230,000.00
# 767                                TRNOVO, PREDMESTJE 349,000.00
# 769                          TRNOVO, ZGORNJI DEL HIŠE 598,000.00
# 771                                          VIŽMARJE 598,000.00
# 815                 ZUPANČIČEVA JAMA, VURNIKOVA ULICA 230,000.00
#
#                                                   OPIS     m2     LETO  \
# 5    ČRNUČE, NARAVA ZASEBNOST TEHNOLOGIJA, 104,3 m2... 104.30 2,025.00
# 37   BRDO, 3 - SOBNO, ATRIJSKO, NADSTANDARDNO, 95,7...  95.79 2,025.00
# 38   BRDO, ATRIJSKO, TOP LOKACIJA, 87,82 m2, 3-sobn...  87.82 2,025.00
# 50   BROD, MARINOVŠEVA CESTA, 86,4 m2, 4-sobno, nov...  86.40 2,026.00
# 54   BS 3, 28 m2, garsonjera, zgrajena l. 1974, 345...  28.00 1,974.00
# 58   BS 3, 81 m2, 3,5-sobno, zgrajeno l. 1981, 250 ...  81.00 1,981.00
# 60   ČRNA VAS, 136,5 m2, 4-sobno, dupleks, zgrajeno... 136.50 2,025.00
# 68   ČRNUČE, 70 m2, 3-sobno, adaptirano l. 2022, 70...  70.00 2,022.00
# 69   ČRNUČE, 74,2 m2, 2,5-sobno, zgrajeno l. 1936, ...  74.20 1,936.00
# 70   ČRNUČE, 79,9 m2, 2-sobno, zgrajeno l. 2022, ad...  79.90 2,022.00
# 73   ČRNUČE, 110 m2, 5 in večsobno, zgrajeno l. 200... 110.00 2,008.00
# 74   ČRNUČE, 138 m2, 5 in večsobno, zgrajeno l. 200... 138.00 2,008.00
# 75   ČRNUČE, NARAVA ZASEBNOST TEHNOLOGIJA, 104,3 m2... 104.30 2,025.00
# 79   DOLGI MOST, 83 m2, 3-sobno, zgrajeno l. 2018, ...  83.00 2,018.00
# 127  KODELJEVO, 91,6 m2, 3-sobno, zgrajeno l. 1936,...  91.60 1,936.00
# 130  KOLEZIJA, 89,4 m2, 3-sobno, zgrajeno l. 1940, ...  89.40 1,940.00
# 139  LJ. BEŽIGRAD, 32 m2, 1-sobno, zgrajeno l. 1900...  32.00 1,900.00
# 156  LJ. BEŽIGRAD, 72,9 m2, 2-sobno, zgrajeno l. 19...  72.90 1,979.00
# 175  LJ. BEŽIGRAD, 95,97 m2, 2,5-sobno, zgrajeno l....  95.97 1,928.00
# 196  LJ. BEŽIGRAD, ČERINOVA ULICA, 54,26 m2, 3-sobn...  54.26 2,025.00
# 207  LJ. BEŽIGRAD, KAMNIŠKA ULICA /VRT, 31 m2, 1-so...  31.00 1,900.00
# 215  LJ. BEŽIGRAD, STOŽICE, 85 m2, 3-sobno, zgrajen...  85.00 1,919.00
# 254  LJ. CENTER, 73 m2, 3-sobno, zgrajeno l. 1918, ...  73.00 1,918.00
# 273  LJ. CENTER, 96,2 m2, 4-sobno, zgrajeno l. 1925...  96.20 1,925.00
# 279  LJ. CENTER, 103 m2, 4-sobno, zgrajeno l. 1925,... 103.00 1,925.00
# 280  LJ. CENTER, 103,2 m2, 4-sobno, zgrajeno l. 192... 103.20 1,925.00
# 345  LJ. CENTER, 308,1 m2, 5 in večsobno, zgrajeno ... 308.10 1,920.00
# 381  LJ. CENTER, GORNJI TRG, 261,7 m2, 5 in večsobn... 261.70 1,550.00
# 382  LJ. CENTER, GORNJI TRG, 261,7 m2, 5 in večsobn... 261.70 1,550.00
# 391  LJ. CENTER, MESARSKA CESTA, 64,1 m2, 2-sobno, ...  64.10 1,882.00
# 417  LJ. CENTER, SLOMŠKOVA 11, 16 m2, garsonjera, z...  16.00 1,968.00
# 426  LJ. CENTER, STARI TRG, 153,8 m2, 4,5-sobno, "p... 153.80 1,650.00
# 431  LJ. CENTER, TRNOVO, 80,9 m2, 2,5-sobno, zgraje...  80.90 1,905.00
# 444  LJ. MOSTE, 60,7 m2, 3-sobno, zgrajeno l. 1936,...  60.70 1,936.00
# 445  LJ. MOSTE, 62 m2, 2,5-sobno, zgrajeno l. 1932,...  62.00 1,932.00
# 447  LJ. MOSTE, 85 m2, 3-sobno, zgrajeno l. 1974, 5...  85.00 1,974.00
# 450  LJ. MOSTE, 110,9 m2, 4-sobno, zgrajeno l. 1900... 110.90 1,900.00
# 452  LJ. MOSTE, 166,4 m2, 3-sobno, zgrajeno l. 1928... 166.40 1,928.00
# 453  LJ. MOSTE, 187 m2, 5 in večsobno, zgrajeno l. ... 187.00 2,009.00
# 455  LJ. MOSTE, ATRIJ, TERASA, 71,3 m2, 3-sobno, v ...  71.30 1,974.00
# 456  LJ. MOSTE, ATRIJSKO STANOVANJE, 71 m2, 4-sobno...  71.00 1,974.00
# 458  LJ. MOSTE, NOVE JARŠE, 71,3 m2, 3-sobno, zgraj...  71.30 1,974.00
# 462  LJ. MOSTE, ŠMARTINSKA, 120 m2, 4,5-sobno, zgra... 120.00 1,936.00
# 463  LJ. MOSTE, V DVOSTANOVANJSKI HIŠI, 110 m2, 3,5... 110.00 1,928.00
# 466  LJ. MOSTE, ZAKOTNIKOVA ULICA, 91 m2, 3-sobno, ...  91.00 1,935.00
# 469  LJ. MOSTE, ZALOŠKA 26, 59 m2, 2-sobno, dupleks...  59.00 1,899.00
# 480  LJ. ŠIŠKA, 40 m2, 2-sobno, zgrajeno l. 1941, 2...  40.00 1,941.00
# 508  LJ. ŠIŠKA, 83,3 m2, 2-sobno, zgrajeno l. 1930,...  83.30 1,930.00
# 525  LJ. ŠIŠKA, KOSEZE, 136,3 m2, 3-sobno, zgrajeno... 136.30 1,933.00
# 584  LJ. VIČ, ROŽNA DOLINA, 262 m2, 4-sobno, zgraje... 262.00 1,920.00
# 614  NOVE JARŠE, POLEG OŠ, S TERASO, 71,3 m2, 3-sob...  71.30 1,974.00
# 625  POLJE, 42,2 m2, 1-sobno, zgrajeno l. 1932, 28 ...  42.20 1,932.00
# 633  PRULE, 121,3 m2, 4-sobno, zgrajeno l. 1934, 67... 121.30 1,934.00
# 639  RAKOVA JELŠA, 136,3 m2, 4-sobno, zgrajeno l. 1... 136.30 1,984.00
# 640  RAKOVA JELŠA, TRNOVO, 184,5 m2, 5 in večsobno,... 184.50 1,972.00
# 656  ROŽNA DOLINA, 142,8 m2, 3-sobno, zgrajeno l. 1... 142.80 1,920.00
# 664  ROŽNA DOLINA, 1KM CENTER, 300M ROŽNIK, TIVOLI,...  53.00 2,023.00
# 666  ROŽNA DOLINA, ATRIJSKO, 3 - SOBNO, NADSTANDARD...  95.79 2,025.00
# 667  ROŽNA DOLINA, ATRIJSKO, TOP LOKACIJA, 112,62 m... 112.62 2,025.00
# 674  RUDNIK, 98,9 m2, 3-sobno, zgrajeno l. 2011, ad...  98.90 2,011.00
# 676  RUDNIK, 123,3 m2, 5 in večsobno, novogradnja, ... 123.30 2,025.00
# 683  RUDNIK, KARLOVŠKO PREDMESTJE, 74 m2, 3-sobno, ...  74.00 2,003.00
# 701  SP. ŠIŠKA, 87,5 m2, 3-sobno, zgrajeno l. 1900,...  87.50 1,900.00
# 708  SREDNJE GAMELJNE, 86 m2, 3,5-sobno, zgrajeno l...  86.00 1,993.00
# 709  STANEŽIČE, 248,8 m2, 3-sobno, zgrajeno l. 2023... 248.80 2,023.00
# 710  STANEŽIČE, 252,8 m2, 3-sobno, zgrajeno l. 2023... 252.80 2,023.00
# 739  ŠENTJAKOB, 138,9 m2, 4-sobno, dupleks, zgrajen... 138.90 2,024.00
# 740  ŠENTJAKOB, 138,9 m2, 4-sobno, dupleks, zgrajen... 138.90 2,024.00
# 741  ŠENTJAKOB, 159,7 m2, 4,5-sobno, dupleks, zgraj... 159.70 2,024.00
# 742  ŠENTJAKOB, 159,7 m2, 4,5-sobno, dupleks, zgraj... 159.70 2,024.00
# 749  ŠENTVID, 101,45 m2, 3-sobno, zgrajeno l. 1920,... 101.45 1,920.00
# 761  TOMAČEVO, 167 m2, 4-sobno, zgrajeno l. 2005, a... 167.00 2,005.00
# 767  TRNOVO, PREDMESTJE, 120 m2, 3-sobno, zgrajeno ... 120.00 1,967.00
# 769  TRNOVO, ZGORNJI DEL HIŠE, 160 m2, 4-sobno, zgr... 160.00 1,938.00
# 771  VIŽMARJE, 114,52 m2, 4-sobno, novogradnja - zg... 114.52 2,024.00
# 815  ZUPANČIČEVA JAMA, VURNIKOVA ULICA, 35 m2, gars...  35.00 1,989.00
#
#     NASTROPJE ZEMLJISCE  cena_m2  adaptirano leto_adaptacije  st_sob  \
# 5         2/2    257 m2 4,688.40        0.00             NaN    3.00
# 37        P/2  40.36 m2 7,085.73        0.00             NaN    3.00
# 38        P/2  24.75 m2 6,780.57        0.00             NaN    3.00
# 50        P/4     97 m2 6,194.51        0.00             NaN    4.00
# 54       6/10    345 m2 6,021.43        0.00             NaN    0.50
# 58          1    250 m2 4,444.44        0.00             NaN    5.00
# 60        P+1    209 m2 3,882.78        0.00             NaN    4.00
# 68       PK/2     70 m2 2,714.29        1.00            2022    3.00
# 69        1/2     17 m2 3,773.58        1.00            2016    5.00
# 70        NaN     45 m2 6,195.24        1.00            2023    2.00
# 73        P/2    208 m2 5,318.18        0.00             NaN    5.00
# 74        P/2    313 m2 4,710.14        0.00             NaN    5.00
# 75        2/2    257 m2 4,688.40        0.00             NaN    3.00
# 79       VP/2     34 m2 5,240.96        0.00             NaN    3.00
# 127         M     46 m2 2,893.01        1.00            2009    3.00
# 130       M/3     29 m2 4,306.49        1.00            2014    3.00
# 139       P/1     20 m2 4,406.25        1.00            2020    1.00
# 156         P     27 m2 4,266.12        1.00            2024    2.00
# 175      VP/2     46 m2 4,886.94        1.00            2010    5.00
# 196      P/12  48.58 m2 7,327.68        0.00             NaN    3.00
# 207       NaN     20 m2 4,548.39        0.00             NaN    1.00
# 215       P/P     85 m2 3,588.24        1.00            2003    3.00
# 254       2/M     50 m2 5,301.37        1.00            2004    3.00
# 273      VP/2    380 m2 5,187.11        1.00            2001    4.00
# 279      VP/2    380 m2 4,844.66        1.00            2016    4.00
# 280        VP    370 m2 4,835.27        1.00            2016    4.00
# 345      VP/1    127 m2 1,785.13        0.00             NaN    5.00
# 381       1/1    289 m2 2,254.49        0.00             NaN    5.00
# 382       1/1    289 m2 2,254.49        0.00             NaN    5.00
# 391       1/2     11 m2 3,276.13        1.00            2007    2.00
# 417      PK/3   1000 m2 5,306.25        0.00             NaN    0.50
# 426       M/4    226 m2 4,551.37        0.00             NaN    5.00
# 431       P/1     85 m2 4,882.57        1.00            2010    5.00
# 444        PK     31 m2 3,624.38        1.00            2019    3.00
# 445      VP/2     45 m2 4,193.55        1.00            2007    5.00
# 447       1/1     55 m2 3,882.35        0.00             NaN    3.00
# 450       NaN    180 m2 3,597.84        0.00             NaN    4.00
# 452         1    142 m2 1,802.88        0.00             NaN    3.00
# 453       NaN    344 m2 3,181.82        1.00            2024    5.00
# 455         P     30 m2 5,328.19        0.00             NaN    3.00
# 456         P     30 m2 5,633.80        0.00             NaN    4.00
# 458         P     30 m2 5,328.19        1.00            2010    3.00
# 462       NaN    169 m2 2,783.33        1.00            2015    5.00
# 463       NaN    142 m2 2,454.55        1.00            2024    5.00
# 466         P    204 m2 3,571.43        1.00            2003    3.00
# 469       1/2     47 m2 4,000.00        1.00            2019    2.00
# 480        PK    236 m2 5,175.00        0.00             NaN    2.00
# 508      VP/1     60 m2 3,481.39        1.00            2010    2.00
# 525         P    340 m2 2,567.87        1.00            2016    3.00
# 584       P/2    306 m2 2,667.94        1.00            2019    4.00
# 614         P     30 m2 5,328.19        0.00             NaN    3.00
# 625      PK/3     28 m2 4,454.98        0.00             NaN    1.00
# 633      VP/2    677 m2 4,534.21        0.00             NaN    4.00
# 639       1/1     47 m2 1,834.19        0.00             NaN    4.00
# 640         1    200 m2 1,788.62        0.00             NaN    5.00
# 656       NaN  306.5 m2 5,035.01        0.00             NaN    3.00
# 664       P/2     62 m2 6,207.55        1.00            2023    2.00
# 666       P/2  47.17 m2 7,085.73        0.00             NaN    3.00
# 667       P/2  24.75 m2 5,287.42        0.00             NaN    3.00
# 674       NaN    148 m2 4,752.28        1.00            2025    3.00
# 676     P+1+M    206 m2 4,047.04        0.00             NaN    5.00
# 683       P/2    156 m2 7,148.65        0.00             NaN    3.00
# 701       1/M     16 m2 3,702.86        1.00            2009    3.00
# 708       1/1    450 m2 3,837.21        1.00            2015    5.00
# 709         P    129 m2 2,713.02        0.00             NaN    3.00
# 710         P    134 m2 2,749.21        0.00             NaN    3.00
# 739       1/2     25 m2 3,160.55        0.00             NaN    4.00
# 740       1/2     25 m2 3,160.55        0.00             NaN    4.00
# 741       1/2     25 m2 2,974.33        0.00             NaN    5.00
# 742       1/2     25 m2 2,974.33        0.00             NaN    5.00
# 749       1/2     17 m2 2,267.13        1.00            2007    3.00
# 761       1/M  270.5 m2 1,377.25        1.00            2017    4.00
# 767       P/2     50 m2 2,908.33        1.00            2019    3.00
# 769         2    261 m2 3,737.50        1.00            2005    4.00
# 771       P/2    150 m2 5,221.80        0.00             NaN    4.00
# 815      VP/4     20 m2 6,571.43        0.00             NaN    0.50
#
#                  kraj mestna_cetrt
# 5              črnuče       Črnuče
# 37               brdo       Rožnik
# 38               brdo       Rožnik
# 50               brod      Šentvid
# 54               bs 3        Jarše
# 58               bs 3        Jarše
# 60           črna vas       Rudnik
# 68             črnuče       Črnuče
# 69             črnuče       Črnuče
# 70             črnuče       Črnuče
# 73             črnuče       Črnuče
# 74             črnuče       Črnuče
# 75             črnuče       Črnuče
# 79         dolgi most          Vič
# 127         kodeljevo        Moste
# 130          kolezija          Vič
# 139          bežigrad     Bežigrad
# 156          bežigrad     Bežigrad
# 175          bežigrad     Bežigrad
# 196          bežigrad     Bežigrad
# 207          bežigrad     Bežigrad
# 215          bežigrad     Bežigrad
# 254            center       Center
# 273            center       Center
# 279            center       Center
# 280            center       Center
# 345            center       Center
# 381            center       Center
# 382            center       Center
# 391            center       Center
# 417            center       Center
# 426            center       Center
# 431            center       Center
# 444             moste        Moste
# 445             moste        Moste
# 447             moste        Moste
# 450             moste        Moste
# 452             moste        Moste
# 453             moste        Moste
# 455             moste        Moste
# 456             moste        Moste
# 458             moste        Moste
# 462             moste        Moste
# 463             moste        Moste
# 466             moste        Moste
# 469             moste        Moste
# 480             šiška        Šiška
# 508             šiška        Šiška
# 525             šiška        Šiška
# 584               vič          Vič
# 614        nove jarše        Jarše
# 625             polje        Polje
# 633             prule       Center
# 639      rakova jelša       Rudnik
# 640            trnovo       Trnovo
# 656      rožna dolina       Rožnik
# 664            center       Center
# 666      rožna dolina       Rožnik
# 667      rožna dolina       Rožnik
# 674            rudnik       Rudnik
# 676            rudnik       Rudnik
# 683            rudnik       Rudnik
# 701             šiška        Šiška
# 708          gameljne  Šmarna gora
# 709         stanežiče  Šmarna gora
# 710         stanežiče  Šmarna gora
# 739         šentjakob      Šentvid
# 740         šentjakob      Šentvid
# 741         šentjakob      Šentvid
# 742         šentjakob      Šentvid
# 749           šentvid      Šentvid
# 761          tomačevo      Posavje
# 767            trnovo       Trnovo
# 769            trnovo       Trnovo
# 771          vižmarje      Šentvid
# 815  zupančičeva jama     Bežigrad

# %% [markdown]
# Stanovanja z pripradajočimi zemljišči so v veliki večini atipična. Zato jih je potrebno ločiti na tipična stanovanja (brez zemljišča) in atipična (s pripadajočimi vrtovi in atriji).

# %% [markdown]
# Ločimo še stanovanja, ki so adaptirana in tista ki niso, ter naredimo nov stolpec o sobnosti. Nekatera stanovanja so veliko premajhna za 4 sobnost itd.

# %%
flet['sobnost_ocenjena'] = flet['m2']

# %%
fleti = pd.DataFrame(flet)

# %%
fleti.head()
# Out:
#                                        NASLOV       CENA  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 460,457.99
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 576,250.99
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 488,949.30
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 570,648.89
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 777,582.99
#
#                                                 OPIS     m2     LETO  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 85...  85.20 2,024.00
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 10... 107.45 2,024.00
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11... 110.40 2,024.00
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11... 112.50 2,024.00
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 16... 162.91 2,024.00
#
#   NASTROPJE ZEMLJISCE  cena_m2  adaptirano leto_adaptacije  st_sob      kraj  \
# 0         1       NaN 5,404.44        0.00             NaN    3.00  bežigrad
# 1         1       NaN 5,362.97        0.00             NaN    4.00  bežigrad
# 2         1       NaN 4,428.89        0.00             NaN    3.00  bežigrad
# 3         P       NaN 5,072.43        0.00             NaN    3.00  bežigrad
# 4         P       NaN 4,773.08        0.00             NaN    4.00  bežigrad
#
#   mestna_cetrt  sobnost_ocenjena
# 0     Bežigrad             85.20
# 1     Bežigrad            107.45
# 2     Bežigrad            110.40
# 3     Bežigrad            112.50
# 4     Bežigrad            162.91

# %% [markdown]
# 📚 Osnova za lestvico sobnosti po kvadraturi, ki sem ti jo predlagal, izhaja iz kombinacije:
# Slovenskih standardov in zakonodaje (minimalni standardi):
#
# Pravilnik o minimalnih tehničnih zahtevah za stanovanja navaja, da mora imeti enosobno stanovanje vsaj 28–30 m², dvosobno pa vsaj 45 m².
#
# Standardna otroška soba ~8–10 m², spalnica ~12–14 m², dnevna soba ~18–25 m², kopalnica ~5 m², kuhinja 6–8 m².
#
# Splošnih urbanističnih norm (in prakse nepremičninskih agencij):
#
# V praksi se 2-sobna stanovanja gibljejo med 45–60 m², 3-sobna med 60–75 m², itd.
#
# 5-sobno stanovanje z 100 m² pomeni, da je vsaka soba mikro enota.
#
# Logike dejanske uporabnosti prostora:
#
# Površina stanovanja mora sorazmerno rasti s številom uporabnih sob. Če ima 100 m² 5 sob, pomeni da so pod-standardno velike ali da nimajo ločenih prostorov (npr. hodnika, utilitya, shramb ipd.).

# %% [markdown]
# | Kvadratura (m²) | Ocenjena sobnost |
# | --------------- | ---------------- |
# | < 35            | 1                |
# | 35–50           | 2                |
# | 51–70           | 3                |
# | 71–90           | 4                |
# | 91–110          | 5                |
# | > 110           | 6+               |

# %%
def oceni_sobnost(m2):
    if pd.isna(m2):
        return None
    if m2 < 35:
        return 1
    elif m2 < 50:
        return 2
    elif m2 < 70:
        return 3
    elif m2 < 90:
        return 4
    elif m2 < 110:
        return 5
    else:
        return 6

# %%
fleti['sobnost_ocenjena'] = fleti['m2'].apply(oceni_sobnost)

# %%
fleti[['OPIS','st_sob', 'sobnost_ocenjena']].dropna().sample(10) # primerjava oglaševane sobnosti z ocenjeno.
# Out:
#                                                   OPIS  st_sob  \
# 202  LJ. BEŽIGRAD, FUNKCINALNO, ČUDOVIT RAZGLED, 42...    1.00
# 330  LJ. CENTER, 184,4 m2, 4-sobno, zgrajeno l. 200...    4.00
# 677  RUDNIK, 143,4 m2, 4-sobno, zgrajeno l. 2015, p...    4.00
# 408  LJ. CENTER, POLJANSKA CESTA 9, 18,7 m2, garson...    0.50
# 397  LJ. CENTER, MIKLOŠIČEVA CESTA, 239 m2, 4-sobno...    4.00
# 135  LITOSTROJ, 78,5 m2, 2-sobno, zgrajeno l. 1952,...    2.00
# 698  SP. ŠIŠKA, 56,4 m2, 2,5-sobno, zgrajeno l. 200...    5.00
# 747  ŠENTVID, 88,7 m2, 3-sobno, zgrajeno l. 1986, a...    3.00
# 30   BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 13...    3.00
# 784  ZALOG, 64 m2, 4-sobno, zgrajeno l. 1997, adapt...    4.00
#
#      sobnost_ocenjena
# 202                 2
# 330                 6
# 677                 6
# 408                 1
# 397                 6
# 135                 4
# 698                 3
# 747                 4
# 30                  6
# 784                 3

# %%
fleti.to_csv('fleti_cleaned', index=False)

# %%
fleti.head()
# Out:
#                                        NASLOV       CENA  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 460,457.99
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 576,250.99
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 488,949.30
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 570,648.89
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA 777,582.99
#
#                                                 OPIS     m2     LETO  \
# 0  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 85...  85.20 2,024.00
# 1  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 10... 107.45 2,024.00
# 2  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11... 110.40 2,024.00
# 3  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 11... 112.50 2,024.00
# 4  BEŽIGRAJSKI DVOR, BEŽIGRAD, ČERINOVA ULICA, 16... 162.91 2,024.00
#
#   NASTROPJE ZEMLJISCE  cena_m2  adaptirano leto_adaptacije  st_sob      kraj  \
# 0         1       NaN 5,404.44        0.00             NaN    3.00  bežigrad
# 1         1       NaN 5,362.97        0.00             NaN    4.00  bežigrad
# 2         1       NaN 4,428.89        0.00             NaN    3.00  bežigrad
# 3         P       NaN 5,072.43        0.00             NaN    3.00  bežigrad
# 4         P       NaN 4,773.08        0.00             NaN    4.00  bežigrad
#
#   mestna_cetrt  sobnost_ocenjena
# 0     Bežigrad                 4
# 1     Bežigrad                 5
# 2     Bežigrad                 6
# 3     Bežigrad                 6
# 4     Bežigrad                 6

# %%
fleti.to_csv('fleti.csv', sep=';', index=False, encoding='utf-8')
